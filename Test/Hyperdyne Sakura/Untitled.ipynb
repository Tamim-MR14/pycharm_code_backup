# %%
import pandas as pd 
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn import preprocessing
from mlxtend.feature_selection import SequentialFeatureSelector as SFS
from sklearn.preprocessing import LabelEncoder
from sklearn.tree import DecisionTreeClassifier
from sklearn.neural_network import MLPClassifier
import numpy as np

df=pd.read_csv("titanicOriginalDataset.csv")

#Fillinf Missing values with a scalar value
df['Age']=df['Age'].fillna(df['Age'].mean())

#Filling NA with maximum occured group
MaxEmbarked=df['Embarked'].dropna().max()
df['Embarked']=df['Embarked'].fillna(MaxEmbarked)

#Getting Maximum Count of a group in a collumn
#max(df.groupby('Embarked').size())

#Dropping Collumn of a Dataframe
cols_drop=['PassengerId','Parch','Ticket','Cabin']
df=df.drop(cols_drop,axis=1)

#Creating new feature
df['new'] = (df['Pclass']==1) & (df['Sex']=='female')


#One-hot-Encoding
df=pd.get_dummies(df,columns=["Pclass","Sex","Embarked"])

#Extracting a portion from values of a collumn
df['Name']=df['Name'].map(lambda x: x.split(',')[1].split('.')[0].strip())

#Label_encoding
df["Name"] = LabelEncoder().fit_transform(df["Name"])



#Number of unique value in a series
#len(df['Name'].unique())

'''target=df['Survived'].values
data=df.drop('Survived',axis=1).values

X_train,X_test,Y_train,Y_test=train_test_split(data, target,test_size=0.2)'''

'''DT=DecisionTreeClassifier( )
sfs1 = SFS(DT, k_features=3, forward=True, floating=False, scoring='accuracy', cv=10)
sfs1 = sfs1.fit(X_train, Y_train)
print('best feature columns:', sfs1.k_feature_idx_)

X_train_sfs = sfs1.transform(np.array(X_train))
X_test_sfs = sfs1.transform(np.array(X_test))

DT.fit(X_train_sfs, Y_train)
print(DT.score(X_test_sfs,Y_test))'''



'''clf = MLPClassifier(max_iter = 200, solver='lbfgs', hidden_layer_sizes = (50,50), activation='relu')
sfs1 = SFS(clf, k_features=5, forward=True, floating=False, scoring='accuracy', cv=10)
sfs1 = sfs1.fit(X_train, Y_train)
print('best feature columns:', sfs1.k_feature_idx_)

X_train_sfs = sfs1.transform(np.array(X_train))
X_test_sfs = sfs1.transform(np.array(X_test))

clf.fit(X_train_sfs, Y_train)
print(clf.score(X_test_sfs,Y_test))'''

#Cross Validation using dataframe

'''k=10
l=int(len(df)/k)

target=df['Survived'].values
data=df.drop('Survived',axis=1).values
X_train,X_test,Y_train,Y_test=train_test_split(data, target,test_size=(l/len(df)))
DT=DecisionTreeClassifier( )
sfs1 = SFS(DT, k_features=5, forward=True, floating=False, scoring='accuracy', cv=10)
sfs1 = sfs1.fit(X_train, Y_train)
print('best feature columns:', sfs1.k_feature_idx_)


i=0
acc=0
for m in range(k):
    if m==k-1:
        test_df=df.iloc[i:len(df)-1,:]
        test_df.index=range(len(test_df))
        train_indexes = set(range(df.shape[0])) - set(range(i,len(df)))
        train_df = df.take(list(train_indexes))
        train_df.index=range(len(train_df))
    else:
        test_df=df.iloc[i:i+l,:]
        test_df.index=range(len(test_df))
        train_indexes = set(range(df.shape[0])) - set(range(i,i+l))
        train_df = df.take(list(train_indexes))
        train_df.index=range(len(train_df))
        
    Y_train=train_df['Survived'].values
    X_train=train_df.drop('Survived',axis=1).values
    Y_test=test_df['Survived'].values
    X_test=test_df.drop('Survived',axis=1).values
    
    
    #sfs1 = sfs1.fit(X_train, Y_train)
    #print('best feature columns:', sfs1.k_feature_idx_)
    X_train_sfs = sfs1.transform(np.array(X_train))
    X_test_sfs = sfs1.transform(np.array(X_test))
    DT.fit(X_train_sfs, Y_train)
    acc=acc+DT.score(X_test_sfs,Y_test)
    i=i+l
print(acc/k)'''

#Cross Validation using array
k=10
i=0
l=int(len(df)/k)
acc=0
target=df['Survived'].values
data=df.drop('Survived',axis=1).values
X_train,X_test,Y_train,Y_test=train_test_split(data, target,test_size=(l/len(df)))
DT=DecisionTreeClassifier( )
sfs1 = SFS(DT, k_features=5, forward=True, floating=False, scoring='accuracy', cv=10)
sfs1 = sfs1.fit(X_train, Y_train)
print('best feature columns:', sfs1.k_feature_idx_)
for m in range(k):
    X_train=[]
    X_test=[]
    Y_train=[]
    Y_test=[]
    s=0
    t=0
    if m==(k-1):
        '''for j in range(len(data)):
            if j in range(i,len(data)):
                X_test.append([])
                Y_test.append([])
                X_test[s].append(data[j])
                Y_test[s].append(target[j])
                s+=1
            else:
                X_train.append([])
                Y_train.append([])
                X_train[t].append(data[j])
                Y_train[t].append(target[j])
                t+=1'''
        X_test=data[i:len(data)-1,:]
        Y_test=target[i:len(data)-1]
        train_indexes = set(range(data.shape[0])) - set(range(i,len(data)))
        X_train=data[list(train_indexes),:]
        Y_train=target[list(train_indexes)]
    else:
        '''for j in range(len(data)):
            if j in range(i,l):
                X_test.append([])
                Y_test.append([])
                X_test[s].append(data[j])
                Y_test[s].append(target[j])
                s+=1
            else:
                X_train.append([])
                Y_train.append([])
                X_train[t].append(data[j])
                Y_train[t].append(target[j])
                t+=1'''
        X_test=data[i:i+l,:]
        Y_test=target[i:i+l]
        train_indexes = set(range(data.shape[0])) - set(range(i,i+l))
        X_train = data[list(train_indexes),:]
        Y_train=target[list(train_indexes)]    
    X_train_sfs = sfs1.transform(np.array(X_train))
    X_test_sfs = sfs1.transform(np.array(X_test))
    DT.fit(X_train_sfs, Y_train)
    acc=acc+DT.score(X_test_sfs,Y_test)
    i=i+l
print(acc/k)
# Out:
# array([[  4.99932139e-01,   5.83541148e-01],
#        [  6.15084779e-01,   1.05027013e-01],
#        [  3.77299215e-01,   8.67588750e-01],
#        [  6.27132284e-01,   3.04527685e-01],
#        [  5.53809123e-01,   9.97777662e-01],
#        [  3.42085181e-01,   8.76597574e-01],
#        [  8.66809018e-01,   5.55072487e-01],
#        [  9.78267030e-01,   3.63108156e-01],
#        [  1.19824083e-01,   8.50004227e-01],
#        [  8.20456247e-01,   3.50260167e-03],
#        [  7.69963940e-01,   8.02351145e-01],
#        [  4.96984609e-01,   7.36127552e-01],
#        [  5.39420985e-01,   9.15686212e-01],
#        [  9.25145938e-01,   2.45575141e-01],
#        [  7.97126196e-01,   8.21479317e-01],
#        [  8.56111803e-01,   8.62720253e-01],
#        [  6.69135145e-01,   8.19451741e-01],
#        [  3.78119313e-01,   3.46659516e-01],
#        [  4.54625016e-01,   4.55353099e-01],
#        [  2.54243985e-01,   7.91046378e-01],
#        [  2.69628497e-01,   4.13608988e-01],
#        [  8.53896030e-01,   3.80796630e-02],
#        [  2.39590964e-01,   5.30534505e-01],
#        [  9.87846468e-01,   2.88364310e-03],
#        [  7.98239276e-01,   9.89924481e-01],
#        [  4.84164405e-01,   8.77928845e-01],
#        [  7.70030383e-01,   8.95728406e-01],
#        [  9.30687792e-01,   5.47297529e-01],
#        [  2.11374851e-02,   8.55732673e-01],
#        [  5.11895180e-01,   4.99830073e-01],
#        [  6.71614102e-01,   3.31958188e-01],
#        [  9.21650333e-01,   6.55507453e-01],
#        [  7.89692241e-01,   4.22199295e-01],
#        [  4.03669538e-01,   6.36771745e-01],
#        [  1.70016037e-01,   2.91977613e-01],
#        [  2.13102552e-01,   4.28027176e-02],
#        [  5.22986261e-01,   7.71913576e-02],
#        [  1.18130268e-01,   9.74687441e-01],
#        [  8.32384526e-01,   9.08690494e-01],
#        [  5.78595643e-01,   8.00729485e-02],
#        [  2.21748857e-01,   5.50768522e-01],
#        [  2.38402548e-01,   8.82901542e-01],
#        [  5.63819810e-02,   9.10150825e-01],
#        [  7.61701067e-01,   5.56273732e-01],
#        [  2.50376688e-01,   4.22436362e-02],
#        [  1.65933732e-01,   8.53763559e-01],
#        [  8.06635333e-01,   3.86016871e-01],
#        [  6.38298505e-01,   9.67428978e-01],
#        [  6.17394748e-01,   2.92149670e-01],
#        [  5.13338199e-01,   8.10978506e-01],
#        [  9.06802485e-01,   7.37676135e-01],
#        [  3.59601174e-01,   2.03365059e-01],
#        [  4.41607721e-01,   3.60995023e-02],
#        [  5.21230765e-01,   9.86806641e-01],
#        [  4.52142952e-03,   1.76237329e-01],
#        [  1.27513348e-01,   2.49742954e-01],
#        [  1.78911196e-01,   7.80696168e-01],
#        [  5.60412174e-01,   3.12270733e-01],
#        [  1.52427719e-01,   8.15007096e-01],
#        [  3.45718041e-01,   2.24050710e-02],
#        [  7.63522719e-01,   5.10493537e-01],
#        [  8.44022772e-01,   7.70533280e-01],
#        [  9.57284076e-01,   4.21489360e-01],
#        [  1.27833510e-01,   2.21171336e-01],
#        [  3.45244223e-01,   9.94699239e-01],
#        [  3.28723691e-01,   5.57467564e-01],
#        [  8.68544504e-01,   8.18010492e-01],
#        [  7.70568481e-01,   8.42081829e-01],
#        [  7.10972238e-01,   1.64315521e-01],
#        [  9.25891874e-01,   3.91516374e-01],
#        [  4.36022531e-01,   5.47303144e-01],
#        [  6.97088781e-01,   8.69991496e-01],
#        [  4.00568485e-01,   3.11030282e-01],
#        [  8.06798628e-01,   4.48885265e-01],
#        [  1.14645613e-01,   7.57669477e-01],
#        [  5.22745437e-01,   3.50271899e-02],
#        [  9.14066293e-01,   3.80556550e-01],
#        [  7.08393009e-02,   3.24685884e-01],
#        [  7.03232582e-01,   5.61930850e-01],
#        [  4.10027748e-01,   2.52571991e-01],
#        [  7.50673109e-01,   9.20630732e-01],
#        [  3.98331002e-01,   7.24293635e-02],
#        [  6.08643851e-01,   6.86212807e-01],
#        [  8.88795322e-01,   8.18757822e-01],
#        [  9.27934875e-02,   8.91945657e-03],
#        [  3.45168796e-01,   3.93543312e-01],
#        [  3.41733050e-01,   8.00602575e-01],
#        [  6.05962393e-01,   3.56774317e-01],
#        [  2.85071212e-01,   2.05294568e-01],
#        [  2.56074164e-02,   4.97879891e-01],
#        [  9.84683604e-01,   1.87674989e-01],
#        [  8.91459018e-01,   8.58399596e-01],
#        [  4.53325416e-01,   1.01135866e-01],
#        [  1.22463847e-01,   7.51766407e-02],
#        [  9.00413548e-01,   8.52035569e-01],
#        [  4.03272446e-02,   8.41483767e-01],
#        [  2.46430468e-03,   9.71461944e-01],
#        [  5.19340947e-02,   1.62180778e-01],
#        [  4.59088625e-01,   2.08947682e-01],
#        [  1.55741824e-01,   6.99935378e-01],
#        [  4.99381697e-01,   9.60872025e-02],
#        [  9.46488080e-02,   1.97345019e-01],
#        [  5.12368205e-01,   3.90270539e-01],
#        [  2.15185742e-01,   8.07682994e-01],
#        [  1.61407236e-01,   7.11463052e-01],
#        [  4.16901486e-01,   1.71824678e-01],
#        [  5.75483724e-01,   1.04695466e-01],
#        [  4.81253623e-01,   7.69624787e-01],
#        [  5.08349220e-01,   5.87437040e-01],
#        [  1.60915339e-02,   2.83002003e-01],
#        [  2.48098370e-03,   6.67451690e-01],
#        [  3.76716934e-01,   7.89087858e-01],
#        [  7.11217185e-02,   4.87642402e-01],
#        [  5.15740231e-01,   8.61170706e-01],
#        [  6.46157068e-01,   4.64312230e-01],
#        [  5.72940803e-01,   1.13551912e-01],
#        [  2.68680910e-01,   7.83083440e-01],
#        [  4.61499098e-01,   8.71141543e-01],
#        [  5.41159570e-01,   5.15367519e-01],
#        [  5.59951123e-01,   1.91448987e-01],
#        [  7.58931657e-01,   4.23199693e-01],
#        [  7.57284572e-01,   7.00777972e-01],
#        [  2.23245473e-01,   5.45465331e-01],
#        [  1.70545757e-01,   9.80402019e-01],
#        [  5.23293286e-02,   8.97377367e-01],
#        [  8.14830960e-01,   6.27332646e-01],
#        [  9.59070902e-01,   3.40104035e-01],
#        [  8.01961309e-01,   6.61714249e-01],
#        [  5.64117595e-01,   4.98841354e-01],
#        [  9.76340117e-01,   2.81341958e-01],
#        [  7.90447813e-01,   4.92530156e-01],
#        [  2.74304774e-01,   7.13952116e-01],
#        [  3.21947721e-01,   3.46794344e-01],
#        [  5.67558053e-01,   9.46977876e-01],
#        [  9.60888277e-01,   7.67213538e-01],
#        [  4.83422142e-02,   2.36327701e-01],
#        [  9.52100233e-01,   4.20122188e-02],
#        [  9.08470404e-01,   9.01427633e-02],
#        [  5.55882394e-01,   5.13919030e-01],
#        [  9.02758285e-01,   1.46951495e-01],
#        [  5.39278473e-01,   4.63462153e-01],
#        [  1.95500821e-01,   7.74464234e-01],
#        [  2.41085627e-02,   7.30899316e-01],
#        [  8.57196272e-01,   8.62014531e-01],
#        [  7.44196335e-01,   9.61636602e-02],
#        [  9.70249515e-01,   7.51731993e-01],
#        [  1.23845560e-01,   1.75587558e-01],
#        [  4.35616443e-01,   8.67735624e-01],
#        [  8.63991924e-01,   7.47800438e-01],
#        [  4.70226795e-02,   3.54506567e-01],
#        [  2.31273763e-01,   9.73524397e-01],
#        [  4.96516461e-01,   7.44943964e-02],
#        [  7.69059936e-01,   1.72948121e-01],
#        [  9.30884062e-01,   4.71797707e-01],
#        [  3.04780866e-01,   6.36241516e-01],
#        [  9.23082964e-01,   2.46116406e-01],
#        [  6.24738888e-01,   1.89374547e-01],
#        [  8.71615677e-01,   7.41240775e-01],
#        [  9.96829733e-01,   4.20579309e-01],
#        [  8.45024533e-01,   3.99861816e-01],
#        [  3.66910259e-01,   2.34179363e-01],
#        [  4.58483139e-01,   4.48708681e-01],
#        [  7.70636714e-01,   5.32398463e-01],
#        [  1.70540463e-01,   8.02272839e-01],
#        [  2.34480931e-01,   3.11964947e-01],
#        [  2.48192112e-01,   3.20840281e-01],
#        [  2.21310349e-02,   9.60149635e-01],
#        [  2.14539821e-01,   8.13235219e-01],
#        [  1.03038278e-01,   1.66059088e-01],
#        [  8.25280067e-01,   4.33781527e-01],
#        [  5.38735846e-01,   8.83080228e-01],
#        [  3.03177731e-01,   1.61571126e-01],
#        [  8.61591695e-03,   9.96839304e-01],
#        [  3.36248011e-01,   1.80756213e-01],
#        [  2.94401682e-01,   2.85531147e-01],
#        [  7.20686110e-01,   7.08580691e-02],
#        [  7.36457794e-03,   4.18505789e-01],
#        [  8.30281433e-01,   6.96625678e-01],
#        [  2.32322117e-01,   4.31779772e-01],
#        [  8.64863604e-01,   8.35296307e-01],
#        [  3.62899857e-01,   3.08436114e-01],
#        [  9.25576872e-01,   2.69589481e-01],
#        [  1.10828235e-01,   1.91130908e-01],
#        [  8.84222890e-01,   7.09724493e-01],
#        [  9.40258673e-01,   6.20395898e-01],
#        [  5.47781550e-01,   4.92044229e-01],
#        [  3.53247046e-01,   3.12272682e-01],
#        [  8.53791288e-01,   5.53915340e-01],
#        [  5.67139851e-01,   3.63551390e-01],
#        [  2.20992395e-01,   4.54516566e-01],
#        [  4.37514519e-01,   5.13598769e-01],
#        [  4.99045959e-01,   6.37515789e-01],
#        [  1.59572613e-01,   9.01318191e-02],
#        [  1.77471209e-01,   8.54049752e-01],
#        [  1.44846414e-01,   2.50988544e-01],
#        [  4.41130812e-01,   6.65994902e-01],
#        [  6.22949669e-01,   6.85235330e-01],
#        [  4.85065967e-01,   1.45383590e-01],
#        [  7.59858188e-01,   6.95966826e-01],
#        [  2.90800456e-01,   7.30050276e-02],
#        [  2.11056482e-01,   2.67297413e-01],
#        [  2.52862179e-02,   4.84778572e-01],
#        [  4.01854961e-01,   5.44675171e-01],
#        [  3.77589803e-01,   3.12288889e-01],
#        [  2.35383009e-01,   1.59858056e-01],
#        [  5.49731505e-01,   4.43191512e-01],
#        [  7.19770515e-01,   7.91327454e-01],
#        [  9.22887110e-01,   4.42348904e-01],
#        [  6.60192955e-01,   9.39175463e-01],
#        [  2.42666628e-01,   2.69724882e-01],
#        [  3.42462476e-01,   1.57637858e-01],
#        [  1.90982931e-01,   7.84032178e-01],
#        [  5.93267967e-01,   9.13253204e-01],
#        [  9.51678379e-01,   7.18026291e-01],
#        [  9.08423416e-02,   7.27180555e-01],
#        [  5.99212142e-01,   8.03911699e-01],
#        [  1.00535037e-01,   9.24592917e-01],
#        [  6.62843985e-01,   1.94668584e-01],
#        [  2.06318239e-01,   4.87869598e-01],
#        [  3.11398816e-01,   4.58574617e-01],
#        [  5.92941025e-02,   8.12536391e-01],
#        [  3.12231172e-01,   2.09645295e-01],
#        [  4.07686181e-01,   2.08615448e-01],
#        [  4.43059250e-01,   8.85308497e-01],
#        [  1.40045127e-01,   8.29214770e-01],
#        [  1.95065061e-01,   5.78223906e-01],
#        [  5.73288992e-01,   5.45279312e-01],
#        [  9.71762741e-01,   5.02801059e-01],
#        [  1.02618218e-01,   2.16728136e-02],
#        [  4.09285232e-01,   6.25640639e-01],
#        [  3.25681126e-01,   1.25363961e-01],
#        [  4.89002593e-01,   4.99528980e-01],
#        [  1.69270199e-01,   1.57099843e-01],
#        [  3.61014484e-01,   2.15353689e-01],
#        [  1.90278284e-01,   1.83782539e-01],
#        [  9.74546213e-01,   7.28847013e-02],
#        [  1.54281444e-01,   7.94224227e-01],
#        [  1.84886271e-01,   3.55750606e-01],
#        [  2.69507832e-01,   6.54431665e-01],
#        [  3.16451456e-01,   9.59857405e-01],
#        [  6.22716118e-01,   8.10200428e-01],
#        [  4.47320536e-02,   6.22966352e-01],
#        [  7.36863042e-01,   6.87607355e-01],
#        [  4.45588303e-01,   1.57224184e-02],
#        [  9.40702976e-01,   7.55436483e-01],
#        [  9.22205814e-01,   8.01698252e-01],
#        [  2.93268118e-01,   8.48474899e-01],
#        [  2.87396593e-02,   8.25938648e-01],
#        [  2.22465597e-01,   4.30464841e-01],
#        [  7.16580797e-01,   5.31645349e-01],
#        [  3.02298237e-01,   6.67864134e-02],
#        [  1.09408682e-01,   7.38821589e-01],
#        [  1.78599867e-02,   2.03217569e-01],
#        [  9.14745899e-01,   9.88538081e-01],
#        [  7.58785714e-02,   5.71899749e-01],
#        [  5.56404778e-01,   1.71798251e-01],
#        [  5.23729953e-01,   4.64528234e-01],
#        [  7.78903338e-01,   9.50906756e-01],
#        [  4.03310891e-01,   9.80871169e-01],
#        [  9.43933096e-01,   5.42562143e-01],
#        [  4.97180877e-01,   2.46645480e-01],
#        [  5.14546716e-01,   6.30663214e-02],
#        [  1.24236989e-02,   8.93499504e-01],
#        [  5.41503219e-01,   8.20555606e-01],
#        [  6.79785492e-01,   8.58674007e-01],
#        [  8.03379273e-01,   7.03491407e-02],
#        [  9.86207774e-01,   6.88335499e-01],
#        [  7.65851969e-01,   6.78364564e-01],
#        [  3.06713067e-01,   4.68225534e-01],
#        [  5.21093448e-02,   1.54034527e-01],
#        [  6.71570406e-01,   6.10161771e-01],
#        [  7.93765086e-01,   3.38585561e-01],
#        [  4.59448952e-01,   2.29780551e-02],
#        [  1.86435258e-01,   3.05549184e-01],
#        [  8.08298461e-01,   4.76633351e-01],
#        [  1.21446743e-01,   4.80690832e-01],
#        [  6.36299396e-01,   7.14662011e-01],
#        [  7.58111342e-02,   6.75104032e-01],
#        [  4.68943583e-01,   6.98568184e-01],
#        [  6.60035876e-01,   9.15429701e-01],
#        [  8.32406350e-01,   3.40646907e-02],
#        [  2.94132093e-01,   6.91186669e-01],
#        [  2.03477266e-01,   1.53752685e-01],
#        [  4.07950867e-02,   7.67045795e-01],
#        [  1.96556646e-01,   2.55328068e-01],
#        [  8.03947726e-01,   3.13556544e-01],
#        [  3.92277832e-01,   9.64851016e-02],
#        [  6.95203223e-01,   3.45344444e-01],
#        [  4.23901667e-03,   6.19366082e-01],
#        [  1.88329212e-01,   6.05588742e-01],
#        [  1.97581937e-01,   9.05724263e-01],
#        [  1.40860245e-01,   9.70278739e-01],
#        [  9.49010582e-01,   9.13769936e-02],
#        [  3.64048953e-01,   7.73975854e-01],
#        [  1.78286153e-02,   7.74745428e-01],
#        [  7.80210338e-01,   1.97551357e-02],
#        [  9.04977812e-01,   5.32765727e-01],
#        [  3.32593633e-01,   2.56021090e-01],
#        [  3.27306304e-01,   7.60646300e-01],
#        [  5.62645428e-01,   2.97192633e-01],
#        [  5.09146296e-02,   6.93406597e-01],
#        [  2.21017323e-01,   1.78567746e-01],
#        [  2.30508367e-01,   9.88050047e-01],
#        [  8.47143109e-01,   7.87875558e-02],
#        [  6.32510690e-01,   5.26387734e-01],
#        [  6.92711033e-01,   7.73581924e-01],
#        [  6.76444314e-01,   1.44947860e-01],
#        [  8.05388510e-01,   4.88246393e-01],
#        [  7.34936942e-01,   8.27198037e-01],
#        [  2.48453447e-01,   8.79836257e-01],
#        [  4.79082218e-01,   4.35213963e-01],
#        [  7.18522762e-02,   1.17080842e-01],
#        [  4.70292991e-01,   5.26951974e-01],
#        [  5.19848764e-01,   1.49387812e-01],
#        [  9.24342739e-01,   3.00759595e-02],
#        [  4.85241092e-01,   3.12805527e-01],
#        [  2.59344779e-01,   6.68693913e-01],
#        [  6.60318681e-01,   8.86542442e-01],
#        [  9.62390657e-01,   2.44920560e-02],
#        [  2.14571292e-01,   7.98531018e-01],
#        [  8.08219397e-01,   8.31153532e-01],
#        [  3.90816443e-01,   5.20554637e-01],
#        [  9.87574675e-01,   7.82605608e-01],
#        [  6.53575015e-01,   1.14844549e-01],
#        [  9.82147911e-01,   2.70811725e-01],
#        [  1.51584366e-01,   6.74803492e-02],
#        [  1.54809858e-01,   4.66071028e-01],
#        [  3.15721781e-02,   9.12285089e-01],
#        [  9.06530735e-01,   7.99767976e-01],
#        [  8.11882224e-01,   6.04661879e-01],
#        [  9.15460598e-01,   9.28159407e-01],
#        [  9.57244466e-01,   1.24189321e-01],
#        [  5.70790285e-01,   6.43548924e-01],
#        [  9.86218476e-01,   5.21936168e-01],
#        [  9.61117603e-01,   5.73596039e-01],
#        [  9.16703820e-01,   8.78438874e-01],
#        [  1.42093129e-01,   1.87130254e-01],
#        [  8.91508016e-01,   2.42178947e-01],
#        [  1.92554572e-01,   5.33670266e-02],
#        [  5.06629607e-01,   2.49176704e-02],
#        [  3.06417742e-01,   2.99462416e-01],
#        [  6.60745356e-01,   6.62976654e-01],
#        [  8.49865475e-01,   3.93192934e-01],
#        [  1.64780905e-01,   4.81826559e-01],
#        [  9.70943111e-01,   4.32342846e-01],
#        [  8.49626013e-01,   2.37962692e-02],
#        [  8.73255552e-01,   6.72988553e-01],
#        [  8.67459594e-01,   2.85299931e-01],
#        [  5.05615538e-01,   8.68832053e-01],
#        [  4.60291039e-01,   5.62195363e-01],
#        [  1.46407712e-01,   6.61697243e-01],
#        [  4.58665021e-01,   6.53768121e-01],
#        [  1.05110322e-01,   7.73066310e-01],
#        [  6.68955515e-01,   6.53592047e-01],
#        [  5.63521682e-01,   8.61084314e-01],
#        [  6.09785305e-01,   4.97119976e-01],
#        [  8.67153437e-01,   7.54164740e-01],
#        [  2.66544335e-01,   8.87494799e-01],
#        [  8.55545730e-01,   5.28455505e-02],
#        [  8.58562838e-01,   6.38729180e-01],
#        [  9.14315373e-01,   7.01980718e-01],
#        [  4.58003364e-01,   1.66849372e-01],
#        [  5.56555620e-01,   1.11702950e-01],
#        [  5.21775298e-01,   8.08772178e-01],
#        [  9.77782005e-02,   5.74575171e-01],
#        [  1.23863460e-01,   3.27213364e-01],
#        [  5.24784556e-01,   8.64249552e-01],
#        [  4.25558762e-02,   5.67595670e-02],
#        [  8.49801795e-01,   7.50339220e-01],
#        [  9.19177616e-01,   9.99288347e-01],
#        [  1.75073388e-01,   7.27251473e-01],
#        [  2.94332633e-02,   1.73875415e-01],
#        [  6.66751601e-01,   1.48527121e-01],
#        [  9.97610898e-02,   4.59694996e-01],
#        [  3.02261223e-01,   5.94420730e-01],
#        [  5.95220773e-01,   7.94980327e-01],
#        [  2.00716320e-01,   9.94010027e-01],
#        [  2.44738719e-01,   5.12792476e-01],
#        [  6.27436480e-01,   1.11872970e-01],
#        [  5.25176625e-01,   4.96135996e-01],
#        [  3.69300033e-01,   2.42834273e-01],
#        [  7.18671041e-01,   8.46220208e-01],
#        [  2.08246962e-01,   9.46871047e-01],
#        [  1.32300292e-01,   3.21507664e-01],
#        [  8.04518457e-01,   3.28068931e-01],
#        [  2.64940585e-01,   3.22659757e-01],
#        [  6.79327421e-01,   1.92778529e-01],
#        [  7.64676164e-01,   8.67382826e-02],
#        [  2.35712994e-01,   3.12313724e-02],
#        [  8.87436599e-01,   3.80869767e-01],
#        [  9.26279483e-01,   6.18701669e-01],
#        [  7.13942505e-01,   5.99419930e-02],
#        [  2.37624638e-01,   5.05569624e-02],
#        [  7.85571780e-01,   6.77838708e-01],
#        [  8.15860595e-02,   6.56870928e-01],
#        [  6.00099680e-02,   1.71818679e-01],
#        [  3.98768917e-01,   4.90997893e-01],
#        [  7.61125389e-01,   7.23806385e-01],
#        [  8.94134017e-01,   1.92030682e-01],
#        [  6.14705359e-01,   3.43570987e-01],
#        [  4.21976861e-01,   4.67548950e-01],
#        [  3.44161825e-01,   5.01794456e-01],
#        [  4.10358576e-01,   9.54248653e-02],
#        [  4.82980310e-01,   7.70580452e-02],
#        [  1.46488573e-01,   8.83085026e-01],
#        [  4.74782898e-01,   9.20684144e-01],
#        [  3.53443309e-01,   2.34502837e-01],
#        [  8.92842196e-01,   1.01739080e-01],
#        [  1.68441613e-01,   7.79928127e-01],
#        [  8.32202123e-01,   9.46178523e-01],
#        [  9.12112771e-01,   7.33175628e-01],
#        [  3.14214297e-01,   8.53865433e-01],
#        [  4.04527419e-01,   7.94092539e-01],
#        [  2.79291553e-01,   3.53597982e-01],
#        [  6.14498501e-01,   6.14099709e-01],
#        [  9.26753490e-01,   9.31785775e-01],
#        [  2.46148834e-01,   5.71751324e-01],
#        [  2.67331091e-01,   7.82289776e-01],
#        [  8.11404936e-01,   7.22757068e-01],
#        [  3.00864524e-01,   9.61170183e-01],
#        [  8.78782617e-01,   6.30839892e-01],
#        [  9.97819584e-01,   9.50210114e-01],
#        [  8.31919031e-01,   7.36812933e-01],
#        [  9.01284191e-01,   6.87937052e-01],
#        [  3.14716597e-01,   8.84025804e-01],
#        [  4.59906316e-01,   1.73582245e-01],
#        [  7.46424033e-01,   3.27890667e-01],
#        [  2.39195071e-02,   9.53379767e-01],
#        [  4.17499258e-01,   2.77536065e-02],
#        [  3.73004788e-01,   8.15968807e-01],
#        [  9.50717372e-01,   8.52038119e-01],
#        [  1.48975207e-01,   2.32289307e-01],
#        [  9.96100698e-01,   9.34919707e-01],
#        [  3.50964644e-01,   4.58295123e-01],
#        [  3.90527689e-01,   3.14727198e-01],
#        [  6.79773879e-01,   5.74120776e-01],
#        [  4.15875615e-01,   9.13348632e-01],
#        [  6.66204731e-01,   2.54860111e-01],
#        [  1.98341534e-01,   7.22755384e-01],
#        [  5.34121866e-01,   5.74087205e-01],
#        [  5.62797864e-01,   1.10208048e-01],
#        [  8.41477846e-01,   9.67831118e-01],
#        [  4.39277286e-01,   7.13019010e-01],
#        [  8.88750198e-01,   6.84990349e-01],
#        [  4.92526167e-02,   1.69364545e-01],
#        [  6.14040861e-01,   5.22586922e-01],
#        [  3.80467906e-01,   8.10584433e-01],
#        [  2.84617188e-01,   9.24487384e-01],
#        [  1.79889919e-01,   8.96750199e-01],
#        [  2.78147872e-01,   7.42711659e-01],
#        [  7.33143078e-01,   6.64025343e-01],
#        [  6.55691173e-02,   7.03414765e-01],
#        [  8.12470733e-02,   3.93789845e-01],
#        [  2.55615189e-01,   6.56154655e-01],
#        [  5.32447863e-01,   5.93390028e-01],
#        [  8.61320025e-01,   9.11113091e-01],
#        [  7.49172260e-01,   4.19107519e-01],
#        [  1.19519217e-01,   4.48451844e-01],
#        [  4.98591779e-01,   4.78311997e-01],
#        [  3.82269310e-01,   2.15125548e-01],
#        [  4.33624013e-01,   8.69762286e-01],
#        [  5.30773548e-01,   4.45980107e-01],
#        [  7.25147112e-02,   6.29923535e-01],
#        [  1.37580194e-01,   7.20116797e-01],
#        [  4.95014686e-01,   5.25641287e-01],
#        [  1.20520534e-01,   7.51193866e-01],
#        [  9.54323829e-01,   5.15118959e-04],
#        [  3.72230854e-01,   9.36454291e-01],
#        [  2.18257269e-01,   3.00741161e-01],
#        [  6.34538255e-01,   9.42427316e-01],
#        [  4.00846289e-01,   1.86445105e-01],
#        [  2.26038161e-01,   5.21089373e-01],
#        [  7.58916149e-01,   3.06309604e-01],
#        [  8.63678364e-01,   3.83078430e-01],
#        [  9.11157595e-01,   6.99797563e-01],
#        [  8.96110101e-01,   6.44620978e-01],
#        [  3.25431759e-01,   2.40412372e-01],
#        [  9.15292278e-01,   2.67063704e-01],
#        [  4.36568821e-01,   2.33107482e-01],
#        [  1.80360513e-02,   2.96858271e-01],
#        [  6.83634919e-01,   2.36808446e-01],
#        [  4.46828591e-01,   1.64335751e-01],
#        [  7.64754998e-01,   6.00584993e-01],
#        [  2.57079983e-01,   9.84090381e-01],
#        [  1.89963639e-01,   7.77157537e-01],
#        [  5.63842592e-01,   6.60142273e-01],
#        [  6.15567176e-01,   6.45263982e-01],
#        [  4.50891176e-01,   9.15599201e-01],
#        [  9.93423371e-01,   8.03628156e-01],
#        [  7.88364282e-01,   1.86081426e-01],
#        [  1.34825395e-01,   1.29637974e-01],
#        [  7.55635320e-01,   9.49430667e-01],
#        [  6.94892243e-01,   1.48746373e-01],
#        [  1.02991291e-02,   4.96892625e-01],
#        [  2.81870245e-01,   1.84223557e-01],
#        [  6.48417637e-02,   1.58337412e-02],
#        [  2.82355694e-01,   4.68705252e-02],
#        [  5.78363109e-01,   3.75593013e-01],
#        [  4.27512397e-01,   7.17333655e-01],
#        [  7.48126005e-01,   7.40379728e-01]])
